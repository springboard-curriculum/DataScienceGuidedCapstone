# %%
#Task 1
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
CCLOAN=pd.read_csv(r'.\DataCapstoneProject2\ccFraudDefault\trainfinal.csv')

# %%
CCLOAN.head(10)
# Out:
#    CLIENTID  LATE_PAYMENT NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0    402072             0         Cash loans           F            N
# 1    384853             0    Revolving loans           M            N
# 2    170510             0         Cash loans           F            Y
# 3    186475             0         Cash loans           F            N
# 4    392298             0         Cash loans           F            N
# 5    416297             0         Cash loans           F            N
# 6    348607             0         Cash loans           M            Y
# 7    350884             0         Cash loans           M            Y
# 8    325558             0         Cash loans           F            N
# 9    153930             0         Cash loans           F            N
#
#   FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 0               N             0           67500.0    191880.0      18976.5
# ...

# %%
CCLOAN.columns
# Out:
# Index(['CLIENTID', 'LATE_PAYMENT', 'NAME_CONTRACT_TYPE', 'CODE_GENDER',
#        'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'CNT_CHILDREN', 'AMT_INCOME_TOTAL',
#        'AMT_CREDIT', 'AMT_ANNUITY', 'AMT_GOODS_PRICE', 'NAME_TYPE_SUITE',
#        'NAME_INCOME_TYPE', 'NAME_EDUCATION_TYPE', 'NAME_FAMILY_STATUS',
#        'NAME_HOUSING_TYPE', 'REGION_POPULATION_RELATIVE', 'DAYS_BIRTH',
#        'DAYS_EMPLOYED', 'DAYS_REGISTRATION', 'DAYS_ID_PUBLISH', 'OWN_CAR_AGE',
#        'FLAG_MOBIL', 'FLAG_EMP_PHONE', 'FLAG_WORK_PHONE', 'FLAG_CONT_MOBILE',
#        'FLAG_PHONE', 'FLAG_EMAIL', 'OCCUPATION_TYPE', 'CNT_FAM_MEMBERS',
#        'REGION_RATING_CLIENT', 'REGION_RATING_CLIENT_W_CITY',
#        'WEEKDAY_APPR_PROCESS_START', 'HOUR_APPR_PROCESS_START',
#        'REG_REGION_NOT_LIVE_REGION', 'REG_REGION_NOT_WORK_REGION',
#        'LIVE_REGION_NOT_WORK_REGION', 'REG_CITY_NOT_LIVE_CITY',
#        'REG_CITY_NOT_WORK_CITY', 'LIVE_CITY_NOT_WORK_CITY',
# ...

# %%
CCLOAN.describe()
# Out:
#             CLIENTID   LATE_PAYMENT   CNT_CHILDREN  AMT_INCOME_TOTAL  \
# count  230633.000000  230633.000000  230633.000000      2.306330e+05
# mean   278019.972138       0.080730       0.416033      1.686759e+05
# std    102829.778088       0.272421       0.721422      2.661192e+05
# min    100003.000000       0.000000       0.000000      2.565000e+04
# 25%    188863.000000       0.000000       0.000000      1.125000e+05
# 50%    278005.000000       0.000000       0.000000      1.440000e+05
# 75%    367042.000000       0.000000       1.000000      2.025000e+05
# max    456255.000000       1.000000      19.000000      1.170000e+08
#
#          AMT_CREDIT    AMT_ANNUITY  AMT_GOODS_PRICE  \
# count  2.306330e+05  230633.000000     2.306330e+05
# mean   5.982199e+05   27076.834213     5.375948e+05
# std    4.015465e+05   14461.128789     3.683561e+05
# min    4.500000e+04       0.000000     4.050000e+04
# 25%    2.700000e+05   16506.000000     2.385000e+05
# ...

# %% [markdown]
# There are features with numbers that are wildly large and some are very small.  I will use log to convert them to be a sizeable number to compare values.  I will use the min and max to see the spread of the value
#
# AMT_INCOME_TOTAL
# AMT_CREDIT
# ---AMT_ANNUITY
# AMT_GOODS_PRICE
#
#
# need to drop Days Employed, figure out AMT_ANNUITY because of 0 value cannot be divided by 0

# %%
num_features=['AMT_INCOME_TOTAL', 'AMT_CREDIT', 'AMT_GOODS_PRICE']

for feature in num_features:
    CCLOAN[feature]=np.log(CCLOAN[feature])

# %%
CCLOAN.head(10)
# Out:
#    CLIENTID  LATE_PAYMENT NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0    402072             0         Cash loans           F            N
# 1    384853             0    Revolving loans           M            N
# 2    170510             0         Cash loans           F            Y
# 3    186475             0         Cash loans           F            N
# 4    392298             0         Cash loans           F            N
# 5    416297             0         Cash loans           F            N
# 6    348607             0         Cash loans           M            Y
# 7    350884             0         Cash loans           M            Y
# 8    325558             0         Cash loans           F            N
# 9    153930             0         Cash loans           F            N
#
#   FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  \
# 0               N             0         11.119883   12.164625      18976.5
# ...
