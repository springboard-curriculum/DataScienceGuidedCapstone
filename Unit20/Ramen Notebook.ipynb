# %%
import pandas as pd

# %%
ramen=pd.read_csv(r'ramen-ratings.csv')

# %%
ramen
# Out:
#       Review #           Brand  \
# 0         2580       New Touch
# 1         2579        Just Way
# 2         2578          Nissin
# 3         2577         Wei Lih
# 4         2576  Ching's Secret
# ...        ...             ...
# 2575         5           Vifon
# 2576         4         Wai Wai
# 2577         3         Wai Wai
# 2578         2         Wai Wai
# 2579         1        Westbrae
#
#                                                 Variety Style   Country  \
# 0                             T's Restaurant Tantanmen    Cup     Japan
# 1     Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack    Taiwan
# 2                         Cup Noodles Chicken Vegetable   Cup       USA
# 3                         GGE Ramen Snack Tomato Flavor  Pack    Taiwan
# 4                                       Singapore Curry  Pack     India
# ...                                                 ...   ...       ...
# 2575  Hu Tiu Nam Vang ["Phnom Penh" style] Asian Sty...  Bowl   Vietnam
# ...

# %%
ramen.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2580 entries, 0 to 2579
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Review #  2580 non-null   int64
#  1   Brand     2580 non-null   object
#  2   Variety   2580 non-null   object
#  3   Style     2578 non-null   object
#  4   Country   2580 non-null   object
#  5   Stars     2580 non-null   float64
#  6   Top Ten   41 non-null     object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 141.2+ KB

# %%
ramen.describe()
# Out:
#           Review #        Stars
# count  2580.000000  2580.000000
# mean   1290.500000     3.650426
# std     744.926171     1.022358
# min       1.000000     0.000000
# 25%     645.750000     3.250000
# 50%    1290.500000     3.750000
# 75%    1935.250000     4.250000
# max    2580.000000     5.000000

# %%
ramen['Top Ten'].fillna(0,inplace = True)

# %%
ramen.head(10)
# Out:
#    Review #           Brand  \
# 0      2580       New Touch
# 1      2579        Just Way
# 2      2578          Nissin
# 3      2577         Wei Lih
# 4      2576  Ching's Secret
# 5      2575   Samyang Foods
# 6      2574         Acecook
# 7      2573     Ikeda Shoku
# 8      2572      Ripe'n'Dry
# 9      2571            KOKA
#
#                                              Variety Style      Country  \
# 0                          T's Restaurant Tantanmen    Cup        Japan
# 1  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack       Taiwan
# 2                      Cup Noodles Chicken Vegetable   Cup          USA
# 3                      GGE Ramen Snack Tomato Flavor  Pack       Taiwan
# 4                                    Singapore Curry  Pack        India
# 5                             Kimchi song Song Ramen  Pack  South Korea
# 6                Spice Deli Tantan Men With Cilantro   Cup        Japan
# ...

# %%
ramen.isna().sum()
# Out:
# Review #    0
# Brand       0
# Variety     0
# Style       2
# Country     0
# Stars       0
# Top Ten     0
# dtype: int64

# %%
aaa=ramen[ramen['Style'].isnull()]

# %%
aaa
# Out:
#       Review #   Brand            Variety Style Country  Stars Top Ten
# 2152       428  Kamfen     E Menm Chicken   NaN   China   3.75       0
# 2442       138    Unif  100 Furong Shrimp   NaN  Taiwan   3.00       0

# %%
ramen['Style'].fillna('None',inplace = True)

# %%
aaa=ramen[ramen['Style'].isnull()]

# %%
aaa
# Out:
# Empty DataFrame
# Columns: [Review #, Brand, Variety, Style, Country, Stars, Top Ten]
# Index: []

# %%
ramen_nissin=ramen[ramen['Brand']=='Nissin']

# %%
ramen_nissin.head(10)
# Out:
#     Review #   Brand                                            Variety Style  \
# 2       2578  Nissin                      Cup Noodles Chicken Vegetable   Cup
# 13      2567  Nissin                       Deka Buto Kimchi Pork Flavor  Bowl
# 14      2566  Nissin  Demae Ramen Bar Noodle Aka Tonkotsu Flavour In...  Pack
# 20      2560  Nissin                          Cup Noodles Laksa Flavour   Cup
# 27      2553  Nissin                 Hakata Ramen Noodle White Tonkotsu  Bowl
# 31      2549  Nissin              Gekikara Ramen Extra Hot Ramen Goreng  Pack
# 39      2541  Nissin  Cup Noodles Very Veggie Spicy Chicken Flavor R...   Cup
# 41      2539  Nissin        Demae Iccho Tonkotsu Flavour Instant Noodle   Cup
# 42      2538  Nissin  Cup Noodles Very Veggie Beef Flavor Ramen Nood...   Cup
# 43      2537  Nissin    Cup NoodlesTom Yam Seafood (More Shrimptacular)   Cup
#
#       Country  Stars Top Ten
# 2         USA   2.25       0
# 13      Japan   4.50       0
# ...

# %%
ramen_nissin[ramen_nissin['Variety']=='Demae Ramen Bar Noodle Aka Tonkotsu Flavour Instant Noodle']
# Out:
#     Review #   Brand                                            Variety Style  \
# 14      2566  Nissin  Demae Ramen Bar Noodle Aka Tonkotsu Flavour In...  Pack
#
#       Country  Stars Top Ten
# 14  Hong Kong    5.0       0

# %%
ramen_nong=ramen[ramen['Brand']=='Nongshim']

# %%
ramen_nong[ramen_nong['Variety']=='Groumet Spicy']
# Out:
# Empty DataFrame
# Columns: [Review #, Brand, Variety, Style, Country, Stars, Top Ten]
# Index: []

# %% [markdown]
# How many country produces ramen

# %%
n=len(ramen['Country'].unique())

print(n)
# Out:
# 38

# %%
ramen['Country'].unique()
# Out:
# array(['Japan', 'Taiwan', 'USA', 'India', 'South Korea', 'Singapore',
#        'Thailand', 'Hong Kong', 'Vietnam', 'Ghana', 'Malaysia',
#        'Indonesia', 'China', 'Nigeria', 'Germany', 'Hungary', 'Mexico',
#        'Fiji', 'Australia', 'Pakistan', 'Bangladesh', 'Canada', 'Nepal',
#        'Brazil', 'UK', 'Myanmar', 'Netherlands', 'Cambodia', 'Finland',
#        'Sarawak', 'Philippines', 'Sweden', 'Colombia', 'Estonia',
#        'Holland', 'Poland', 'Dubai', 'United States'], dtype=object)
