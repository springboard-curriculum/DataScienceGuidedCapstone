# %% [markdown]
# import data from source
# import Pandas
# Import CSV file

# %%
## Task 1
##import pandas
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sns
import numpy as np
import os


##import inforamtion for world back of population
#with open(r'D:\springboard\DataScienceGuidedCapstone\Unit7\DataCapstoneProject2\data_worldbank_population.csv') as birthratecsvfile:
LaborRate = pd.read_csv(r'D:\springboard\DataScienceGuidedCapstone\Unit7\DataCapstoneProject2\AllLabour_1960_2020.csv',header=0)

# %%
# Task 2
#verify columns names and type of object
#LaborRate.info()

# %%
# Task 3
#Validate if there are duplicate country name and country code.  There does not seem to be any duplicate.
#LaborRate[['CountryName','CountryCode']].nunique()

# %%
# Task 4
#view data and see a lot of NaN, and notice the number XX.XX is actually in millions
#LaborRate.head(25)

# %%
# Task 5
#create new df to move data for japan and United states into
LaborRate2 = LaborRate.loc[LaborRate['CountryName'].isin(['Japan','United States'])]
LaborRate2
# Out:
#        CountryName CountryCode       1960       1961       1962       1963  \
# 117          Japan         JPN        NaN        NaN        NaN        NaN
# 249  United States         USA  56.400002  56.299999  55.799999  55.200001
#
#           1964       1965       1966       1967  ...       2011       2012  \
# 117        NaN        NaN        NaN        NaN  ...  42.560001  41.900002
# 249  55.299999  55.799999  57.099998  57.700001  ...  54.968899  55.816101
#
#           2013       2014     2015       2016       2017       2018  \
# 117  42.599998  43.000000  43.0000  44.799999  44.599998  47.599998
# 249  55.049599  55.007801  54.9963  55.164902  55.466400  55.215599
#
#           2019  2020
# 117  49.299999   NaN
# 249  55.876400   NaN
#
# [2 rows x 63 columns]

# %%
# Task 6
LaborRate2.columns
# Out:
# Index(['Year', '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967',
#        '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976',
#        '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985',
#        '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994',
#        '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003',
#        '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012',
#        '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020'],
#       dtype='object')

# %%
# Out:
# <bound method DataFrame.info of               Year       1960       1961       1962       1963       1964  \
# 117          Japan        NaN        NaN        NaN        NaN        NaN
# 249  United States  56.400002  56.299999  55.799999  55.200001  55.299999
#
#           1965       1966       1967       1968  ...       2011       2012  \
# 117        NaN        NaN        NaN  55.799999  ...  42.560001  41.900002
# 249  55.799999  57.099998  57.700001  57.700001  ...  54.968899  55.816101
#
#           2013       2014     2015       2016       2017       2018  \
# 117  42.599998  43.000000  43.0000  44.799999  44.599998  47.599998
# 249  55.049599  55.007801  54.9963  55.164902  55.466400  55.215599
#
#           2019  2020
# 117  49.299999   NaN
# 249  55.876400   NaN
#
# [2 rows x 62 columns]>

# %%
# Task 7
#drop CountryCode column as it doesnt provide useful data
LaborRate2= LaborRate2.drop(['CountryCode'],axis = 1)
LaborRate2
# Out:
#        CountryName       1960       1961       1962       1963       1964  \
# 117          Japan        NaN        NaN        NaN        NaN        NaN
# 249  United States  56.400002  56.299999  55.799999  55.200001  55.299999
#
#           1965       1966       1967       1968  ...       2011       2012  \
# 117        NaN        NaN        NaN  55.799999  ...  42.560001  41.900002
# 249  55.799999  57.099998  57.700001  57.700001  ...  54.968899  55.816101
#
#           2013       2014     2015       2016       2017       2018  \
# 117  42.599998  43.000000  43.0000  44.799999  44.599998  47.599998
# 249  55.049599  55.007801  54.9963  55.164902  55.466400  55.215599
#
#           2019  2020
# 117  49.299999   NaN
# 249  55.876400   NaN
#
# [2 rows x 62 columns]

# %%
# Task 8
LaborRate2.rename(columns={'CountryName':'Year'},inplace = True)

# %%
# Task 9
LaborRate2
# Out:
#               Year       1960       1961       1962       1963       1964  \
# 117          Japan        NaN        NaN        NaN        NaN        NaN
# 249  United States  56.400002  56.299999  55.799999  55.200001  55.299999
#
#           1965       1966       1967       1968  ...       2011       2012  \
# 117        NaN        NaN        NaN  55.799999  ...  42.560001  41.900002
# 249  55.799999  57.099998  57.700001  57.700001  ...  54.968899  55.816101
#
#           2013       2014     2015       2016       2017       2018  \
# 117  42.599998  43.000000  43.0000  44.799999  44.599998  47.599998
# 249  55.049599  55.007801  54.9963  55.164902  55.466400  55.215599
#
#           2019  2020
# 117  49.299999   NaN
# 249  55.876400   NaN
#
# [2 rows x 62 columns]

# %%
# Task 9
#Transpose axis for LaborRate2
LaborRateR = LaborRate2.T
LaborRateR
# Out:
#             117            249
# Year      Japan  United States
# 1960        NaN      56.400002
# 1961        NaN      56.299999
# 1962        NaN      55.799999
# 1963        NaN      55.200001
# ...         ...            ...
# 2016  44.799999      55.164902
# 2017  44.599998        55.4664
# 2018  47.599998      55.215599
# 2019  49.299999        55.8764
# 2020        NaN            NaN
#
# [62 rows x 2 columns]

# %%
#
#created a new column for index
LaborRateR.reset_index(inplace=True)

# %%
# Task 11

LaborRateR
# Out:
#    index        117            249
# 0   Year      Japan  United States
# 1   1960        NaN      56.400002
# 2   1961        NaN      56.299999
# 3   1962        NaN      55.799999
# 4   1963        NaN      55.200001
# ..   ...        ...            ...
# 57  2016  44.799999      55.164902
# 58  2017  44.599998        55.4664
# 59  2018  47.599998      55.215599
# 60  2019  49.299999        55.8764
# 61  2020        NaN            NaN
#
# [62 rows x 3 columns]

# %%
# Task 10
#used this to move the first row of data as header for data
LaborRate.columns = LaborRateR.iloc[0]
LaborRateR = LaborRateR.drop(LaborRateR.index[0])

# %%
#DO NOT DELETE 
#use to change col to new name
#LaborRateT.columns = LaborRateT.iloc[0]
#LaborRateT = LaborRateT.drop(LaborRateT.index[0])

# %%
LaborRateT
# Out:
# Year      Japan United States
# 1960        NaN     56.400002
# 1961        NaN     56.299999
# 1962        NaN     55.799999
# 1963        NaN     55.200001
# 1964        NaN     55.299999
# ...         ...           ...
# 2016  44.799999     55.164902
# 2017  44.599998       55.4664
# 2018  47.599998     55.215599
# 2019  49.299999       55.8764
# 2020        NaN           NaN
#
# [61 rows x 2 columns]

# %%
# Out:
# Year index      Japan United States
# 0     1960        NaN     56.400002
# 1     1961        NaN     56.299999
# 2     1962        NaN     55.799999
# 3     1963        NaN     55.200001
# 4     1964        NaN     55.299999
# ..     ...        ...           ...
# 56    2016  44.799999     55.164902
# 57    2017  44.599998       55.4664
# 58    2018  47.599998     55.215599
# 59    2019  49.299999       55.8764
# 60    2020        NaN           NaN
#
# [61 rows x 3 columns]

# %%
LaborRateTT = LaborRateT.index

# %%
LaborRateR.columns
# Out:
# Index(['Year', 'Japan', 'United States'], dtype='object', name=0)

# %%
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-137-1dad17a31b2f> in <module>
# ----> 1 sns.relplot(x =LaborRateR["Year"], y=LaborRateR["United States"], data=LaborRateR,kind='line')
#
# D:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# D:\ProgramData\Anaconda3\lib\site-packages\seaborn\relational.py in relplot(x, y, hue, size, style, data, row, col, col_wrap, row_order, col_order, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, dashes, style_order, legend, kind, height, aspect, facet_kws, units, **kwargs)
#    1021
#    1022     # Draw the plot
# -> 1023     g.map_dataframe(func, **plot_kws)
#    1024
#    1025     # Label the axes
#
# D:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py in map_dataframe(self, func, *args, **kwargs)
#     748
#     749             # Draw the plot
# --> 750             self._facet_plot(func, ax, args, kwargs)
#     751
#     752         # Finalize the annotations and layout
#
# D:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py in _facet_plot(self, func, ax, plot_args, plot_kwargs)
#     773             plot_args = []
#     774             plot_kwargs["ax"] = ax
# --> 775         func(*plot_args, **plot_kwargs)
#     776
#     777         # Sort out the supporting information
#
# D:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# D:\ProgramData\Anaconda3\lib\site-packages\seaborn\relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend, ax, **kwargs)
#     701     p._attach(ax)
#     702
# --> 703     p.plot(ax, kwargs)
#     704     return ax
#     705
#
# D:\ProgramData\Anaconda3\lib\site-packages\seaborn\relational.py in plot(self, ax, kws)
#     497                     err = "estimator must be None when specifying units"
#     498                     raise ValueError(err)
# --> 499                 x, y, y_ci = self.aggregate(y, x, u)
#     500             else:
#     501                 y_ci = None
#
# D:\ProgramData\Anaconda3\lib\site-packages\seaborn\relational.py in aggregate(self, vals, grouper, units)
#     399         # Group and get the aggregation estimate
#     400         grouped = vals.groupby(grouper, sort=self.sort)
# --> 401         est = grouped.agg(func)
#     402
#     403         # Exit early if we don't want a confidence interval
#
# D:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     239
#     240         if isinstance(func, str):
# --> 241             return getattr(self, func)(*args, **kwargs)
#     242
#     243         elif isinstance(func, abc.Iterable):
#
# D:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in mean(self, numeric_only)
#    1494         Name: B, dtype: float64
#    1495         """
# -> 1496         return self._cython_agg_general(
#    1497             "mean",
#    1498             alt=lambda x, axis: Series(x).mean(numeric_only=numeric_only),
#
# D:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#    1079
#    1080         if not output:
# -> 1081             raise DataError("No numeric types to aggregate")
#    1082
#    1083         return self._wrap_aggregated_output(output, index=self.grouper.result_index)
#
# DataError: No numeric types to aggregate

# %%
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-127-28a9b5549921> in <module>
#       2 #look at seaborn
#       3
# ----> 4 sns.relplot(x =LaborRateR['Year'],y=LaborRateR['United States'],kind='line')
#       5
#       6 #print (x)
#
# D:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# D:\ProgramData\Anaconda3\lib\site-packages\seaborn\relational.py in relplot(x, y, hue, size, style, data, row, col, col_wrap, row_order, col_order, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, dashes, style_order, legend, kind, height, aspect, facet_kws, units, **kwargs)
#    1021
#    1022     # Draw the plot
# -> 1023     g.map_dataframe(func, **plot_kws)
#    1024
#    1025     # Label the axes
#
# D:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py in map_dataframe(self, func, *args, **kwargs)
#     748
#     749             # Draw the plot
# --> 750             self._facet_plot(func, ax, args, kwargs)
#     751
#     752         # Finalize the annotations and layout
#
# D:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py in _facet_plot(self, func, ax, plot_args, plot_kwargs)
#     773             plot_args = []
#     774             plot_kwargs["ax"] = ax
# --> 775         func(*plot_args, **plot_kwargs)
#     776
#     777         # Sort out the supporting information
#
# D:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# D:\ProgramData\Anaconda3\lib\site-packages\seaborn\relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend, ax, **kwargs)
#     701     p._attach(ax)
#     702
# --> 703     p.plot(ax, kwargs)
#     704     return ax
#     705
#
# D:\ProgramData\Anaconda3\lib\site-packages\seaborn\relational.py in plot(self, ax, kws)
#     497                     err = "estimator must be None when specifying units"
#     498                     raise ValueError(err)
# --> 499                 x, y, y_ci = self.aggregate(y, x, u)
#     500             else:
#     501                 y_ci = None
#
# D:\ProgramData\Anaconda3\lib\site-packages\seaborn\relational.py in aggregate(self, vals, grouper, units)
#     399         # Group and get the aggregation estimate
#     400         grouped = vals.groupby(grouper, sort=self.sort)
# --> 401         est = grouped.agg(func)
#     402
#     403         # Exit early if we don't want a confidence interval
#
# D:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     239
#     240         if isinstance(func, str):
# --> 241             return getattr(self, func)(*args, **kwargs)
#     242
#     243         elif isinstance(func, abc.Iterable):
#
# D:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in mean(self, numeric_only)
#    1494         Name: B, dtype: float64
#    1495         """
# -> 1496         return self._cython_agg_general(
#    1497             "mean",
#    1498             alt=lambda x, axis: Series(x).mean(numeric_only=numeric_only),
#
# D:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#    1079
#    1080         if not output:
# -> 1081             raise DataError("No numeric types to aggregate")
#    1082
#    1083         return self._wrap_aggregated_output(output, index=self.grouper.result_index)
#
# DataError: No numeric types to aggregate

# %%
LaborRateT
# Out:
# Year      Japan United States
# 1960        NaN     56.400002
# 1961        NaN     56.299999
# 1962        NaN     55.799999
# 1963        NaN     55.200001
# 1964        NaN     55.299999
# ...         ...           ...
# 2016  44.799999     55.164902
# 2017  44.599998       55.4664
# 2018  47.599998     55.215599
# 2019  49.299999       55.8764
# 2020        NaN           NaN
#
# [61 rows x 2 columns]

# %%
LaborR
# Out:
# Year index      Japan United States
# 0     1960        NaN     56.400002
# 1     1961        NaN     56.299999
# 2     1962        NaN     55.799999
# 3     1963        NaN     55.200001
# 4     1964        NaN     55.299999
# ..     ...        ...           ...
# 56    2016  44.799999     55.164902
# 57    2017  44.599998       55.4664
# 58    2018  47.599998     55.215599
# 59    2019  49.299999       55.8764
# 60    2020        NaN           NaN
#
# [61 rows x 3 columns]

# %%
#works
from matplotlib import rcParams
rcParams['figure.figsize'] = 40,6
plt.plot(LaborRateT['Japan'])
plt.plot(LaborRateT['United States'])
plt.title('Japan and US Employees')
plt.xlabel('Year')
plt.ylabel('Millions Employed')
plt.grid(True)
#below will set legend as NAN
plt.legend(LaborRateT['Japan']);

# %%
#matplot works but missing some data

y = LaborRateT['Japan']
y2 = LaborRateT['United States']

x = LaborRateT.index
fig = plt.figure()
ax = plt.subplot(111)
ax.plot(x, y, label='Japan')
ax.plot(x, y2, label='United States')
plt.title('Legend inside')
ax.legend()
plt.show()

# %%
#Task

y = LaborRateT['Japan']
y2 = LaborRateT['United States']

x = LaborRateT.index
fig = plt.figure()
ax = plt.subplot(111)
ax.plot(x, y, label='Japan')
ax.plot(x, y2, label='United States')
plt.title('Legend inside')
ax.legend()
plt.show()

# %%
LaborRateT.Japan=LaborRateT.Japan.astype('float')
LaborRateT['United States']=LaborRateT['United States'].astype('float')

# %%
sns.lineplot(data=LaborRateT)
# Out:
# <AxesSubplot:>
