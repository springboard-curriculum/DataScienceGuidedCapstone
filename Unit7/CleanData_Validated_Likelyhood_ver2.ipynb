# %%
#Task 1
#import pandas
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sns
import numpy as np
import os
import sklearn


##import inforamtion from Kaggle 
CCLoan = pd.read_csv(r'D:\springboard\DataScienceGuidedCapstone\Unit7\DataCapstoneProject2\ccFraudDefault\application_data_RemoveNormalized.csv',header=0)

# %%
#Task 2.0
#preview first 25 row to verify data was imported correctly

CCLoan.head(25)
# Out:
#     SK_ID_CURR  TARGET NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 0       100002       1         Cash loans           M            N
# 1       100003       0         Cash loans           F            N
# 2       100004       0    Revolving loans           M            Y
# 3       100006       0         Cash loans           F            N
# 4       100007       0         Cash loans           M            N
# 5       100008       0         Cash loans           M            N
# 6       100009       0         Cash loans           F            Y
# 7       100010       0         Cash loans           M            Y
# 8       100011       0         Cash loans           F            N
# 9       100012       0    Revolving loans           M            N
# 10      100014       0         Cash loans           F            N
# 11      100015       0         Cash loans           F            N
# 12      100016       0         Cash loans           F            N
# ...

# %%
#Task 2.0.1
#rename certian column to be more readable
CCLoan.rename(columns={'SK_ID_CURR':'CLIENTID','TARGET':'LATE_PAYMENT'},inplace = True)

# %%
#Task 2.1
#Total row of record is 307511 and now 52 columns
CCLoan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307511 entries, 0 to 307510
# Data columns (total 52 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   CLIENTID                     307511 non-null  int64
#  1   LATE_PAYMENT                 307511 non-null  int64
#  2   NAME_CONTRACT_TYPE           307511 non-null  object
#  3   CODE_GENDER                  307511 non-null  object
#  4   FLAG_OWN_CAR                 307511 non-null  object
#  5   FLAG_OWN_REALTY              307511 non-null  object
#  6   CNT_CHILDREN                 307511 non-null  int64
#  7   AMT_INCOME_TOTAL             307511 non-null  float64
#  8   AMT_CREDIT                   307511 non-null  float64
#  9   AMT_ANNUITY                  307499 non-null  float64
#  10  AMT_GOODS_PRICE              307233 non-null  float64
#  11  NAME_TYPE_SUITE              306219 non-null  object
# ...

# %%
#Task 2.2
# review data to see if data should be kept and clarify what is that data

aaa=CCLoan.isna().sum()
aaa.sort_values(ascending = False,)
# Out:
# FONDKAPREMONT_MODE             210295
# OWN_CAR_AGE                    202929
# WALLSMATERIAL_MODE             156341
# HOUSETYPE_MODE                 154297
# EMERGENCYSTATE_MODE            145755
# OCCUPATION_TYPE                 96391
# AMT_REQ_CREDIT_BUREAU_YEAR      41519
# AMT_REQ_CREDIT_BUREAU_QRT       41519
# NAME_TYPE_SUITE                  1292
# OBS_30_CNT_SOCIAL_CIRCLE         1021
# DEF_30_CNT_SOCIAL_CIRCLE         1021
# OBS_60_CNT_SOCIAL_CIRCLE         1021
# DEF_60_CNT_SOCIAL_CIRCLE         1021
# AMT_GOODS_PRICE                   278
# AMT_ANNUITY                        12
# CNT_FAM_MEMBERS                     2
# DAYS_LAST_PHONE_CHANGE              1
# LIVE_CITY_NOT_WORK_CITY             0
# ORGANIZATION_TYPE                   0
# REG_CITY_NOT_LIVE_CITY              0
# LIVE_REGION_NOT_WORK_REGION         0
# REG_REGION_NOT_WORK_REGION          0
# REG_REGION_NOT_LIVE_REGION          0
# HOUR_APPR_PROCESS_START             0
# WEEKDAY_APPR_PROCESS_START          0
# ...

# %%
#Task 3.1.0
# review data to see if data should be kept and clarify what is that data
# validated that if someone does not own a card the data is NaN
CCLoan_car=CCLoan[CCLoan['FLAG_OWN_CAR']=='N']
CCLoan_car =CCLoan_car[CCLoan_car['OWN_CAR_AGE'].isna()]

CCLoan_car[['CLIENTID','LATE_PAYMENT','FLAG_OWN_CAR','OWN_CAR_AGE','HOUSETYPE_MODE',]].head(10)
# Out:
# Empty DataFrame
# Columns: [CLIENTID, LATE_PAYMENT, FLAG_OWN_CAR, OWN_CAR_AGE, HOUSETYPE_MODE]
# Index: []

# %%
# Out:
# False

# %%
#CCLoan_car =CCLoan_car[CCLoan_car['OWN_CAR_AGE'].isna()]
CCLoan_car
# Out:
# Empty DataFrame
# ...

# %%
#Task 3.1.1
#view  infor of OWN_CAR_AGE is what type of data.  I find it is Float so i would need to put 0 instead of NA for this value
CCLoan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 307511 entries, 0 to 307510
# Data columns (total 52 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   CLIENTID                     307511 non-null  int64
#  1   LATE_PAYMENT                 307511 non-null  int64
#  2   NAME_CONTRACT_TYPE           307511 non-null  object
#  3   CODE_GENDER                  307511 non-null  object
#  4   FLAG_OWN_CAR                 307511 non-null  object
#  5   FLAG_OWN_REALTY              307511 non-null  object
#  6   CNT_CHILDREN                 307511 non-null  int64
#  7   AMT_INCOME_TOTAL             307511 non-null  float64
#  8   AMT_CREDIT                   307511 non-null  float64
#  9   AMT_ANNUITY                  307499 non-null  float64
#  10  AMT_GOODS_PRICE              307233 non-null  float64
#  11  NAME_TYPE_SUITE              306219 non-null  object
# ...

# %%
#Task 3.2.0
#to decifer who own car you will need to use FLAG_OWN_CAR to see if they have car.  I am settinb
CCLoan['OWN_CAR_AGE']=CCLoan['OWN_CAR_AGE'].replace(np.nan, 0)

# %%
#Task 3.2.1
#Validate that NaN is now 0 instead of NaN
CCLoan_car=CCLoan[CCLoan['FLAG_OWN_CAR']=='N']
CCLoan_car[['CLIENTID','LATE_PAYMENT','FLAG_OWN_CAR','OWN_CAR_AGE','FONDKAPREMONT_MODE','WALLSMATERIAL_MODE','HOUSETYPE_MODE','EMERGENCYSTATE_MODE']].head(10)
# Out:
#     CLIENTID  LATE_PAYMENT FLAG_OWN_CAR  OWN_CAR_AGE FONDKAPREMONT_MODE  \
# 0     100002             1            N          0.0   reg oper account
# 1     100003             0            N          0.0   reg oper account
# 3     100006             0            N          0.0                NaN
# 4     100007             0            N          0.0                NaN
# 5     100008             0            N          0.0                NaN
# 8     100011             0            N          0.0                NaN
# 9     100012             0            N          0.0                NaN
# 10    100014             0            N          0.0                NaN
# 11    100015             0            N          0.0                NaN
# 12    100016             0            N          0.0   reg oper account
#
#    WALLSMATERIAL_MODE  HOUSETYPE_MODE EMERGENCYSTATE_MODE
# 0        Stone, brick  block of flats                  No
# 1               Block  block of flats                  No
# ...

# %%
#Task 3.3.1
#Change NaN for WALLSMATERIAL_MODE & HouseTypeMode to NA as unknown material or house  type
CCLoan['WALLSMATERIAL_MODE']=CCLoan['WALLSMATERIAL_MODE'].replace(np.nan, 'unknown')
CCLoan['HOUSETYPE_MODE']=CCLoan['HOUSETYPE_MODE'].replace(np.nan, 'unknown')

CCLoan[['CLIENTID','LATE_PAYMENT','FLAG_OWN_CAR','OWN_CAR_AGE','FONDKAPREMONT_MODE','WALLSMATERIAL_MODE','HOUSETYPE_MODE','EMERGENCYSTATE_MODE']].head(10)
# Out:
#    CLIENTID  LATE_PAYMENT FLAG_OWN_CAR  OWN_CAR_AGE FONDKAPREMONT_MODE  \
# 0    100002             1            N          0.0   reg oper account
# 1    100003             0            N          0.0   reg oper account
# 2    100004             0            Y         26.0                NaN
# 3    100006             0            N          0.0                NaN
# 4    100007             0            N          0.0                NaN
# 5    100008             0            N          0.0                NaN
# 6    100009             0            Y         17.0                NaN
# 7    100010             0            Y          8.0                NaN
# 8    100011             0            N          0.0                NaN
# 9    100012             0            N          0.0                NaN
#
#   WALLSMATERIAL_MODE  HOUSETYPE_MODE EMERGENCYSTATE_MODE
# 0       Stone, brick  block of flats                  No
# 1              Block  block of flats                  No
# ...

# %%
#Task 2.3.2
#View data
#CCLoan[['CLIENTID','LATE_PAYMENT','FLAG_OWN_CAR','OWN_CAR_AGE','FONDKAPREMONT_MODE','WALLSMATERIAL_MODE','HOUSETYPE_MODE','EMERGENCYSTATE_MODE']].head(25)

# %% [markdown]
# View Data to see if I should drop more columns

# %%
#Task 3.3.2
#see what data is null, total row is 307511 and the below is top 5 row with 214000+ rows are null

aaa=CCLoan.isna().sum()
aaa.sort_values(ascending = False,)
# Out:
# FONDKAPREMONT_MODE             210295
# EMERGENCYSTATE_MODE            145755
# OCCUPATION_TYPE                 96391
# AMT_REQ_CREDIT_BUREAU_YEAR      41519
# AMT_REQ_CREDIT_BUREAU_QRT       41519
# NAME_TYPE_SUITE                  1292
# DEF_60_CNT_SOCIAL_CIRCLE         1021
# OBS_60_CNT_SOCIAL_CIRCLE         1021
# DEF_30_CNT_SOCIAL_CIRCLE         1021
# OBS_30_CNT_SOCIAL_CIRCLE         1021
# AMT_GOODS_PRICE                   278
# AMT_ANNUITY                        12
# CNT_FAM_MEMBERS                     2
# DAYS_LAST_PHONE_CHANGE              1
# WALLSMATERIAL_MODE                  0
# ORGANIZATION_TYPE                   0
# LIVE_CITY_NOT_WORK_CITY             0
# REG_CITY_NOT_WORK_CITY              0
# REG_CITY_NOT_LIVE_CITY              0
# LIVE_REGION_NOT_WORK_REGION         0
# REG_REGION_NOT_WORK_REGION          0
# REG_REGION_NOT_LIVE_REGION          0
# HOUR_APPR_PROCESS_START             0
# WEEKDAY_APPR_PROCESS_START          0
# REGION_RATING_CLIENT_W_CITY         0
# ...

# %%
#Task 3.4.1

#drop column FONDKAPREMONT_MODE, EMERGENCYSTATE_MODE
CCLoan=CCLoan.drop(['FONDKAPREMONT_MODE','EMERGENCYSTATE_MODE'],axis=1)


#validate columns are dropped
#validated the columns are no longer there and now see next 5 columns
bbb=CCLoan.isna().sum()
bbb.sort_values(ascending = False)

threshold = len(CCLoan)*.4
columns_drop = bbb.loc[bbb > threshold].index
# Out:
# OCCUPATION_TYPE                96391
# AMT_REQ_CREDIT_BUREAU_QRT      41519
# AMT_REQ_CREDIT_BUREAU_YEAR     41519
# NAME_TYPE_SUITE                 1292
# OBS_60_CNT_SOCIAL_CIRCLE        1021
# DEF_30_CNT_SOCIAL_CIRCLE        1021
# OBS_30_CNT_SOCIAL_CIRCLE        1021
# DEF_60_CNT_SOCIAL_CIRCLE        1021
# AMT_GOODS_PRICE                  278
# AMT_ANNUITY                       12
# CNT_FAM_MEMBERS                    2
# DAYS_LAST_PHONE_CHANGE             1
# REG_REGION_NOT_WORK_REGION         0
# REGION_RATING_CLIENT               0
# REGION_RATING_CLIENT_W_CITY        0
# WEEKDAY_APPR_PROCESS_START         0
# HOUR_APPR_PROCESS_START            0
# REG_REGION_NOT_LIVE_REGION         0
# LIVE_CITY_NOT_WORK_CITY            0
# LIVE_REGION_NOT_WORK_REGION        0
# REG_CITY_NOT_LIVE_CITY             0
# REG_CITY_NOT_WORK_CITY             0
# FLAG_EMAIL                         0
# HOUSETYPE_MODE                     0
# WALLSMATERIAL_MODE                 0
# ...

# %%
### 

threshold = len(CCLoan)*.4
columns_drop = bbb.loc[bbb > threshold].index
columns_drop

# %%
#Task 3.4.1.0
CCLoan[['CLIENTID','LATE_PAYMENT','OCCUPATION_TYPE','AMT_REQ_CREDIT_BUREAU_QRT','AMT_REQ_CREDIT_BUREAU_YEAR','NAME_TYPE_SUITE','AMT_ANNUITY','AMT_GOODS_PRICE']].head(30)
# Out:
#     CLIENTID  LATE_PAYMENT OCCUPATION_TYPE  AMT_REQ_CREDIT_BUREAU_QRT  \
# 0     100002             1        Laborers                        0.0
# 1     100003             0      Core staff                        0.0
# 2     100004             0        Laborers                        0.0
# 3     100006             0        Laborers                        NaN
# 4     100007             0      Core staff                        0.0
# 5     100008             0        Laborers                        1.0
# 6     100009             0     Accountants                        1.0
# 7     100010             0        Managers                        0.0
# 8     100011             0             NaN                        0.0
# 9     100012             0        Laborers                        NaN
# 10    100014             0      Core staff                        0.0
# 11    100015             0             NaN                        0.0
# ...

# %%
#Task 3.5.1
#update 
#AMT_REQ_CREDIT_BUREAU_QRT  >>> 0.0 because instead of blank but no credit history
#AMT_REQ_CREDIT_BUREAU_YEAR >>> 0.0 because instead of blank but no credit history
#NAME_TYPE_SUITE >>> N/A
#OCCUPATION_TYPE >>> N/A

CCLoan['AMT_REQ_CREDIT_BUREAU_QRT']=CCLoan['AMT_REQ_CREDIT_BUREAU_QRT'].replace(np.nan, 0.0)
CCLoan['AMT_REQ_CREDIT_BUREAU_YEAR']=CCLoan['AMT_REQ_CREDIT_BUREAU_YEAR'].replace(np.nan, 0.0)
CCLoan['NAME_TYPE_SUITE']=CCLoan['NAME_TYPE_SUITE'].replace(np.nan, 'N/A')
CCLoan['OCCUPATION_TYPE']=CCLoan['OCCUPATION_TYPE'].replace(np.nan, 'N/A')
CCLoan['DEF_60_CNT_SOCIAL_CIRCLE']=CCLoan['DEF_60_CNT_SOCIAL_CIRCLE'].replace(np.nan, 'N/A')
CCLoan['OBS_60_CNT_SOCIAL_CIRCLE']=CCLoan['OBS_60_CNT_SOCIAL_CIRCLE'].replace(np.nan, 'N/A')
CCLoan['DEF_30_CNT_SOCIAL_CIRCLE']=CCLoan['DEF_30_CNT_SOCIAL_CIRCLE'].replace(np.nan, 'N/A')
CCLoan['OBS_30_CNT_SOCIAL_CIRCLE']=CCLoan['OBS_30_CNT_SOCIAL_CIRCLE'].replace(np.nan, 'N/A')

# %%
#Task 3.5.2.0
CCLoan[['CLIENTID','LATE_PAYMENT','OCCUPATION_TYPE','AMT_REQ_CREDIT_BUREAU_QRT','AMT_REQ_CREDIT_BUREAU_YEAR','NAME_TYPE_SUITE','AMT_ANNUITY','AMT_GOODS_PRICE']].head(30)
# Out:
#     CLIENTID  LATE_PAYMENT OCCUPATION_TYPE  AMT_REQ_CREDIT_BUREAU_QRT  \
# 0     100002             1        Laborers                        0.0
# 1     100003             0      Core staff                        0.0
# 2     100004             0        Laborers                        0.0
# 3     100006             0        Laborers                        0.0
# 4     100007             0      Core staff                        0.0
# 5     100008             0        Laborers                        1.0
# 6     100009             0     Accountants                        1.0
# 7     100010             0        Managers                        0.0
# 8     100011             0             N/A                        0.0
# 9     100012             0        Laborers                        0.0
# 10    100014             0      Core staff                        0.0
# 11    100015             0             N/A                        0.0
# ...

# %%
#Task 3.5.3
#validate columns are dropped
#validated the columns are no longer there and now see next 5 columns
ccc=CCLoan.isna().sum()
ccc.sort_values(ascending = False)
# Out:
# AMT_GOODS_PRICE                278
# AMT_ANNUITY                     12
# CNT_FAM_MEMBERS                  2
# DAYS_LAST_PHONE_CHANGE           1
# CLIENTID                         0
# REG_CITY_NOT_LIVE_CITY           0
# OCCUPATION_TYPE                  0
# REGION_RATING_CLIENT             0
# REGION_RATING_CLIENT_W_CITY      0
# WEEKDAY_APPR_PROCESS_START       0
# HOUR_APPR_PROCESS_START          0
# REG_REGION_NOT_LIVE_REGION       0
# REG_REGION_NOT_WORK_REGION       0
# LIVE_REGION_NOT_WORK_REGION      0
# LIVE_CITY_NOT_WORK_CITY          0
# REG_CITY_NOT_WORK_CITY           0
# FLAG_PHONE                       0
# ORGANIZATION_TYPE                0
# HOUSETYPE_MODE                   0
# WALLSMATERIAL_MODE               0
# OBS_30_CNT_SOCIAL_CIRCLE         0
# DEF_30_CNT_SOCIAL_CIRCLE         0
# OBS_60_CNT_SOCIAL_CIRCLE         0
# DEF_60_CNT_SOCIAL_CIRCLE         0
# AMT_REQ_CREDIT_BUREAU_QRT        0
# FLAG_EMAIL                       0
# FLAG_CONT_MOBILE                 0
# ...

# %%
#Task 3.6.1
#take a mean of AMT_GOODS_PRICE and fill in NaN
CCLoan['AMT_GOODS_PRICE']=CCLoan['AMT_GOODS_PRICE'].replace(np.nan,CCLoan['AMT_GOODS_PRICE'].mean())

ccc=CCLoan.isna().sum()
ccc.sort_values(ascending = False)
# Out:
# AMT_ANNUITY                    12
# CNT_FAM_MEMBERS                 2
# DAYS_LAST_PHONE_CHANGE          1
# CLIENTID                        0
# REG_CITY_NOT_LIVE_CITY          0
# OCCUPATION_TYPE                 0
# REGION_RATING_CLIENT            0
# REGION_RATING_CLIENT_W_CITY     0
# WEEKDAY_APPR_PROCESS_START      0
# HOUR_APPR_PROCESS_START         0
# REG_REGION_NOT_LIVE_REGION      0
# REG_REGION_NOT_WORK_REGION      0
# LIVE_REGION_NOT_WORK_REGION     0
# LIVE_CITY_NOT_WORK_CITY         0
# REG_CITY_NOT_WORK_CITY          0
# FLAG_PHONE                      0
# ORGANIZATION_TYPE               0
# HOUSETYPE_MODE                  0
# WALLSMATERIAL_MODE              0
# OBS_30_CNT_SOCIAL_CIRCLE        0
# DEF_30_CNT_SOCIAL_CIRCLE        0
# OBS_60_CNT_SOCIAL_CIRCLE        0
# DEF_60_CNT_SOCIAL_CIRCLE        0
# AMT_REQ_CREDIT_BUREAU_QRT       0
# FLAG_EMAIL                      0
# FLAG_CONT_MOBILE                0
# LATE_PAYMENT                    0
# ...

# %%
CCLoan.fillna([],0)

# %%
#Task 3.7.1
#take a mean of  and fill in 0
CCLoan['AMT_ANNUITY']=CCLoan['AMT_ANNUITY'].replace(np.nan,0)

ccc=CCLoan.isna().sum()
ccc.sort_values(ascending = False)
# Out:
# CNT_FAM_MEMBERS                2
# DAYS_LAST_PHONE_CHANGE         1
# CLIENTID                       0
# REG_CITY_NOT_LIVE_CITY         0
# FLAG_EMAIL                     0
# OCCUPATION_TYPE                0
# REGION_RATING_CLIENT           0
# REGION_RATING_CLIENT_W_CITY    0
# WEEKDAY_APPR_PROCESS_START     0
# HOUR_APPR_PROCESS_START        0
# REG_REGION_NOT_LIVE_REGION     0
# REG_REGION_NOT_WORK_REGION     0
# LIVE_REGION_NOT_WORK_REGION    0
# REG_CITY_NOT_WORK_CITY         0
# LATE_PAYMENT                   0
# LIVE_CITY_NOT_WORK_CITY        0
# ORGANIZATION_TYPE              0
# HOUSETYPE_MODE                 0
# WALLSMATERIAL_MODE             0
# OBS_30_CNT_SOCIAL_CIRCLE       0
# DEF_30_CNT_SOCIAL_CIRCLE       0
# OBS_60_CNT_SOCIAL_CIRCLE       0
# DEF_60_CNT_SOCIAL_CIRCLE       0
# AMT_REQ_CREDIT_BUREAU_QRT      0
# FLAG_PHONE                     0
# FLAG_CONT_MOBILE               0
# FLAG_WORK_PHONE                0
# FLAG_EMP_PHONE                 0
# ...

# %%
CCLoan.fillna({'AMT_GOODS_PRICE':  CCLoan.AMT_GOODS_PRICE.mean(), 'AMT_ANNUITY': 0})

# %%
#Task 3.8.1
CCLoan_amt = CCLoan[CCLoan['CNT_FAM_MEMBERS'].isna()]
CCLoan_amt[['CLIENTID','LATE_PAYMENT','OCCUPATION_TYPE','CNT_FAM_MEMBERS','CNT_CHILDREN','AMT_ANNUITY','AMT_GOODS_PRICE']].head(30)
# Out:
#         CLIENTID  LATE_PAYMENT OCCUPATION_TYPE  CNT_FAM_MEMBERS  CNT_CHILDREN  \
# 41982     148605             0        Managers              NaN             0
# 187348    317181             0     Accountants              NaN             0
#
#         AMT_ANNUITY  AMT_GOODS_PRICE
# 41982       33750.0    538396.207429
# 187348      29250.0    538396.207429

# %%
#Task 3.8.2

CCLoan['CNT_FAM_MEMBERS']=CCLoan['CNT_FAM_MEMBERS'].replace(np.nan,0)

ccc=CCLoan.isna().sum()
ccc.sort_values(ascending = False)
# Out:
# DAYS_LAST_PHONE_CHANGE         1
# CLIENTID                       0
# REG_CITY_NOT_LIVE_CITY         0
# FLAG_EMAIL                     0
# OCCUPATION_TYPE                0
# CNT_FAM_MEMBERS                0
# REGION_RATING_CLIENT           0
# REGION_RATING_CLIENT_W_CITY    0
# WEEKDAY_APPR_PROCESS_START     0
# HOUR_APPR_PROCESS_START        0
# REG_REGION_NOT_LIVE_REGION     0
# REG_REGION_NOT_WORK_REGION     0
# LIVE_REGION_NOT_WORK_REGION    0
# REG_CITY_NOT_WORK_CITY         0
# LATE_PAYMENT                   0
# LIVE_CITY_NOT_WORK_CITY        0
# ORGANIZATION_TYPE              0
# HOUSETYPE_MODE                 0
# WALLSMATERIAL_MODE             0
# OBS_30_CNT_SOCIAL_CIRCLE       0
# DEF_30_CNT_SOCIAL_CIRCLE       0
# OBS_60_CNT_SOCIAL_CIRCLE       0
# DEF_60_CNT_SOCIAL_CIRCLE       0
# AMT_REQ_CREDIT_BUREAU_QRT      0
# FLAG_PHONE                     0
# FLAG_CONT_MOBILE               0
# FLAG_WORK_PHONE                0
# FLAG_EMP_PHONE                 0
# ...

# %%
CCLoan[['CLIENTID','LATE_PAYMENT','OCCUPATION_TYPE','CNT_FAM_MEMBERS','CNT_CHILDREN','DAYS_LAST_PHONE_CHANGE','AMT_ANNUITY','AMT_GOODS_PRICE']].head(30)
# Out:
#     CLIENTID  LATE_PAYMENT OCCUPATION_TYPE  CNT_FAM_MEMBERS  CNT_CHILDREN  \
# 0     100002             1        Laborers              1.0             0
# 1     100003             0      Core staff              2.0             0
# 2     100004             0        Laborers              1.0             0
# 3     100006             0        Laborers              2.0             0
# 4     100007             0      Core staff              1.0             0
# 5     100008             0        Laborers              2.0             0
# 6     100009             0     Accountants              3.0             1
# 7     100010             0        Managers              2.0             0
# 8     100011             0             N/A              2.0             0
# 9     100012             0        Laborers              1.0             0
# 10    100014             0      Core staff              3.0             1
# 11    100015             0             N/A              2.0             0
# ...

# %%
#Task 3.9.1
CCLoan_amt = CCLoan[CCLoan['DAYS_LAST_PHONE_CHANGE'].isna()]
CCLoan_amt[['CLIENTID','LATE_PAYMENT','OCCUPATION_TYPE','CNT_FAM_MEMBERS','CNT_CHILDREN','DAYS_LAST_PHONE_CHANGE','AMT_ANNUITY','AMT_GOODS_PRICE']].head(30)

# %%
#Task 3.9.2
CCLoan['DAYS_LAST_PHONE_CHANGE']=CCLoan['DAYS_LAST_PHONE_CHANGE'].replace(np.nan,0.0)

ccc=CCLoan.isna().sum()
ccc.sort_values(ascending = False)
# Out:
# CLIENTID                       0
# REG_CITY_NOT_LIVE_CITY         0
# FLAG_EMAIL                     0
# OCCUPATION_TYPE                0
# CNT_FAM_MEMBERS                0
# REGION_RATING_CLIENT           0
# REGION_RATING_CLIENT_W_CITY    0
# WEEKDAY_APPR_PROCESS_START     0
# HOUR_APPR_PROCESS_START        0
# REG_REGION_NOT_LIVE_REGION     0
# REG_REGION_NOT_WORK_REGION     0
# LIVE_REGION_NOT_WORK_REGION    0
# REG_CITY_NOT_WORK_CITY         0
# LATE_PAYMENT                   0
# LIVE_CITY_NOT_WORK_CITY        0
# ORGANIZATION_TYPE              0
# HOUSETYPE_MODE                 0
# WALLSMATERIAL_MODE             0
# OBS_30_CNT_SOCIAL_CIRCLE       0
# DEF_30_CNT_SOCIAL_CIRCLE       0
# OBS_60_CNT_SOCIAL_CIRCLE       0
# DEF_60_CNT_SOCIAL_CIRCLE       0
# DAYS_LAST_PHONE_CHANGE         0
# AMT_REQ_CREDIT_BUREAU_QRT      0
# FLAG_PHONE                     0
# FLAG_CONT_MOBILE               0
# FLAG_WORK_PHONE                0
# FLAG_EMP_PHONE                 0
# ...

# %%
#Task 6.1
# find if a person with late payment will have more cars or less
CCLoan['FLAG_OWN_CAR'].count()
# Out:
# 307511

# %%
#Task 6.1.1
LatePay= CCLoan.loc[CCLoan['LATE_PAYMENT']==1]
NoLate = CCLoan.loc[CCLoan['LATE_PAYMENT']==0]

# %%
#Task 6.1.2

#percent of people who are late vs nonlate on cc payment
print ('% of Late Payment : ' +str(len(LatePay['CLIENTID'])/len(CCLoan['CLIENTID'])*100))
print ('% in good standing : ' +str(len(NoLate['CLIENTID'])/len(CCLoan['CLIENTID'])*100))


#there is a 8% default on credit
# Out:
# % of Late Payment : 8.072881945686495
# % in good standing : 91.92711805431351

# %%
#Task 6.1.5
NoLate
# Out:
#         CLIENTID  LATE_PAYMENT NAME_CONTRACT_TYPE CODE_GENDER FLAG_OWN_CAR  \
# 1         100003             0         Cash loans           F            N
# 2         100004             0    Revolving loans           M            Y
# 3         100006             0         Cash loans           F            N
# 4         100007             0         Cash loans           M            N
# 5         100008             0         Cash loans           M            N
# ...          ...           ...                ...         ...          ...
# 307505    456249             0         Cash loans           F            N
# 307506    456251             0         Cash loans           M            N
# 307507    456252             0         Cash loans           F            N
# 307508    456253             0         Cash loans           F            N
# 307510    456255             0         Cash loans           F            N
#
# ...

# %%
#Task 6.1.6
#Find what is percentage who is Late Payment that owns a car

owncar_LatePayment=(len(LatePay[LatePay['FLAG_OWN_CAR']=='Y']))/len(LatePay['FLAG_OWN_CAR'])*100
print ('% whom has defaulted: '+ str(owncar_LatePayment))


owncar_NoLate=(len(NoLate[NoLate['FLAG_OWN_CAR']=='Y']))/len(NoLate['FLAG_OWN_CAR'])*100
print('% that has not defaulted : '+ str(owncar_NoLate))


#there is a 4% difference where person who owns car that didnt default as to to whom has
# Out:
# % whom has defaulted: 30.517623363544814
# % that has not defaulted : 34.317582052170955

# %%
#Task 6.1.8
#Find what is percentage who is Late Payment that owns reality
# Out:
# % whom has defaulted: 30.517623363544814
# % that has not defaulted : 34.317582052170955

# %%
#Task 8
# save the state_summary separately.
CCLoan.to_csv(r'D:\springboard\DataScienceGuidedCapstone\Unit7\DataCapstoneProject2\ccFraudDefault\Cleaned_app_data.csv')

# %%
#
#should do a graph of client ID vs the amount AMT_GOOD_PRICE / AMT_CREDIT

# %%
#
#should do a graph of client ID vs the amount AMT_CREDIT / AMT_INCOME_TOTAL

# %%
#Task x.6.5
#total people with cars and then information if they are late or not late on payment
car_owners = CCLoan[CCLoan['FLAG_OWN_CAR']== 'Y']
car_owner_T = car_owners[car_owners['LATE_PAYMENT']== 1]
car_owner_NT = car_owners[car_owners['LATE_PAYMENT']== 0]
print('Total Count:    '+ str(car_owners['LATE_PAYMENT'].count()))  #.sum() properway
print('LatePayment:    '+ str(car_owner_T['LATE_PAYMENT'].count()))
print('No LatePayment: '+ str(car_owner_NT['LATE_PAYMENT'].count()))

# %%
#Task 6
#Find the % that is late vs not late
#8.1 % of total client is late
VS = (Late['CLIENTID'].count() / CCLoan['CLIENTID'].count())*100

print(VS)

# %%
#Task 7
#get a list of clients who have a late installment
Late = CCLoan.loc[CCLoan['LATE_PAYMENT']. isin([1])]

# %%
#Task 8
#count number of Target are late ---24825 is the output
Late.count()

# %%
#Task 9
#try to find relationship where 
Late.head(25)

# %%
#Task 10
Late[['CLIENTID','AMT_INCOME_TOTAL','AMT_CREDIT','AMT_ANNUITY','AMT_GOODS_PRICE']].head(25)

# %%
#Task 11
Late.describe()

# %%
#Task 21
#put non late payment into another DF so I can graph the latepayment vs income
NonLate = CCLoan.loc[CCLoan['LATE_PAYMENT']. isin([0])]

# %%
CCLoan[['CLIENTID','LATE_PAYMENT','AMT_INCOME_TOTAL','AMT_CREDIT','AMT_ANNUITY','AMT_GOODS_PRICE','FLAG_OWN_CAR']].head(25)

# %% [markdown]
# #Task 22
# #graph amt_credit vs amt_annuity
#
# y = NonLate['AMT_CREDIT']
# y2 = NonLate['AMT_ANNUITY']
#
# x = NonLate ['CLIENT']
# fig = plt.figure()
# ax = plt.subplot()
# ax.plot(x, y, label='Credit Amount')
# ax.plot(x, y2, label='Loan Payment')
# plt.title('Legend inside')
# ax.legend()

# %%
#GRAPH target vs points FLAG_OWN_CAR, FLAG_OWN_REALTY

# %%
#Task 1000
#testsplit  dataset
from sklearn.model_selection import train_test_split

train_test_split(x,y,test_size = .2)
