# %%
data visualizqation
statistical graphing

# %%
#Task 1
#import pandas
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sns
import numpy as np
import os
import sklearn


##import inforamtion from Kaggle 
CCLoan = pd.read_csv(r'D:\springboard\DataScienceGuidedCapstone\Unit7\DataCapstoneProject2\ccFraudDefault\application_data.csv',header=0)

# %%
#Task 2
#rename certian column to be more readable
CCLoan.rename(columns={'SK_ID_CURR':'CLIENTID','TARGET':'LATE_PAYMENT'},inplace = True)

# %% [markdown]
# Task 5

# %%
#Task 5.1
#take a look what is 25%, 50% and 75% of credit of loan

np.percentile(CCLoan['AMT_CREDIT'],[25,50,75])
# Out:
# array([270000., 513531., 808650.])

# %%
#Task 5.2
#take a look what is 25%, 50% and 75% of credit of loan

np.percentile(CCLoan['AMT_CREDIT'],[25,50,75])
# Out:
# array([270000., 513531., 808650.])

# %%
#Task 5.3
#take a look what is 25%, 50% and 75% of credit of loan

np.percentile(CCLoan['AMT_CREDIT'],[25,50,75])
# Out:
# array([270000., 513531., 808650.])

# %%
sns.pairplot(CCLoan)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-c95dfc4d26ba> in <module>
# ----> 1 sns.pairplot(CCLoan)
#
# D:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# D:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    1987     # Set up the PairGrid
#    1988     grid_kws.setdefault("diag_sharey", diag_kind == "hist")
# -> 1989     grid = PairGrid(data, vars=vars, x_vars=x_vars, y_vars=y_vars, hue=hue,
#    1990                     hue_order=hue_order, palette=palette, corner=corner,
#    1991                     height=height, aspect=aspect, dropna=dropna, **grid_kws)
#
# D:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# D:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py in __init__(self, data, hue, hue_order, palette, hue_kws, vars, x_vars, y_vars, corner, diag_sharey, height, aspect, layout_pad, despine, dropna, size)
#    1181         figsize = len(x_vars) * height * aspect, len(y_vars) * height
#    1182
# -> 1183         fig, axes = plt.subplots(len(y_vars), len(x_vars),
#    1184                                  figsize=figsize,
#    1185                                  sharex="col", sharey="row",
#
# D:\ProgramData\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*args, **kwargs)
#     449                 "parameter will become keyword-only %(removal)s.",
#     450                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 451         return func(*args, **kwargs)
#     452
#     453     return wrapper
#
# D:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in subplots(nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw, **fig_kw)
#    1286     """
#    1287     fig = figure(**fig_kw)
# -> 1288     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1289                        squeeze=squeeze, subplot_kw=subplot_kw,
#    1290                        gridspec_kw=gridspec_kw)
#
# D:\ProgramData\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*args, **kwargs)
#     449                 "parameter will become keyword-only %(removal)s.",
#     450                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 451         return func(*args, **kwargs)
#     452
#     453     return wrapper
#
# D:\ProgramData\Anaconda3\lib\site-packages\matplotlib\figure.py in subplots(self, nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw)
#    1520         if gridspec_kw is None:
#    1521             gridspec_kw = {}
# -> 1522         return (self.add_gridspec(nrows, ncols, figure=self, **gridspec_kw)
#    1523                 .subplots(sharex=sharex, sharey=sharey, squeeze=squeeze,
#    1524                           subplot_kw=subplot_kw))
#
# D:\ProgramData\Anaconda3\lib\site-packages\matplotlib\gridspec.py in subplots(self, sharex, sharey, squeeze, subplot_kw)
#     334                 subplot_kw["sharex"] = shared_with[sharex]
#     335                 subplot_kw["sharey"] = shared_with[sharey]
# --> 336                 axarr[row, col] = figure.add_subplot(
#     337                     self[row, col], **subplot_kw)
#     338
#
# D:\ProgramData\Anaconda3\lib\site-packages\matplotlib\figure.py in add_subplot(self, *args, **kwargs)
#    1402             ax = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1403
# -> 1404         return self._add_axes_internal(key, ax)
#    1405
#    1406     def _add_axes_internal(self, key, ax):
#
# D:\ProgramData\Anaconda3\lib\site-packages\matplotlib\figure.py in _add_axes_internal(self, key, ax)
#    1407         """Private helper for `add_axes` and `add_subplot`."""
#    1408         self._axstack.add(key, ax)
# -> 1409         self.sca(ax)
#    1410         ax._remove_method = self.delaxes
#    1411         self.stale = True
#
# D:\ProgramData\Anaconda3\lib\site-packages\matplotlib\figure.py in sca(self, a)
#    2067     def sca(self, a):
#    2068         """Set the current axes to be *a* and return *a*."""
# -> 2069         self._axstack.bubble(a)
#    2070         self._axobservers.process("_axes_change_event", self)
#    2071         return a
#
# D:\ProgramData\Anaconda3\lib\site-packages\matplotlib\figure.py in bubble(self, a)
#     102         stack, to the top.
#     103         """
# --> 104         return super().bubble(self._entry_from_axes(a))
#     105
#     106     def add(self, key, a):
#
# D:\ProgramData\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py in bubble(self, o)
#     626                 top_elements.append(elem)
#     627             else:
# --> 628                 self.push(elem)
#     629         for _ in top_elements:
#     630             self.push(o)
#
# D:\ProgramData\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py in push(self, o)
#     584         *o* is returned.
#     585         """
# --> 586         self._elements = self._elements[:self._pos + 1] + [o]
#     587         self._pos = len(self._elements) - 1
#     588         return self()
#
# KeyboardInterrupt:

# %% [markdown]
# #Task 10
# it just runs and didnt graphy
# #test graph swarm plot
# sns.swarmplot(y='LATE_PAYMENT', x ='NAME_CONTRACT_TYPE', data=CCLoan)
# plt.xlabel('Type of Loan')
# plt.ylabel('Late Payment')
# plt.show()
